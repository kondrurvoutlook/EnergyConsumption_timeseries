# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("/content/train_IxoE5JN.csv")

# %%
df.shape
# Out:
# (94992, 3)

# %%
df.head()
# Out:
#    row_id             datetime       energy
# 0       1  2008-03-01 00:00:00  1259.985563
# 1       2  2008-03-01 01:00:00  1095.541500
# 2       3  2008-03-01 02:00:00  1056.247500
# 3       4  2008-03-01 03:00:00  1034.742000
# 4       5  2008-03-01 04:00:00  1026.334500

# %%
df.tail()
# Out:
#        row_id             datetime     energy
# 94987   94988  2018-12-31 19:00:00  2528.4468
# 94988   94989  2018-12-31 20:00:00  2461.8836
# 94989   94990  2018-12-31 21:00:00  2365.9944
# 94990   94991  2018-12-31 22:00:00  2342.9428
# 94991   94992  2018-12-31 23:00:00  2180.2176

# %%
df.shape
# Out:
# (94992, 3)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 94992 entries, 0 to 94991
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   row_id    94992 non-null  int64
#  1   datetime  94992 non-null  object
#  2   energy    93092 non-null  float64
# dtypes: float64(1), int64(1), object(1)
# memory usage: 2.2+ MB

# %%
df.isna().sum()
# Out:
# row_id         0
# datetime       0
# energy      1900
# dtype: int64

# %%
df.describe()
# Out:
#              row_id        energy
# count  94992.000000  93092.000000
# mean   47496.500000   1702.995014
# std    27421.972723    369.322103
# min        1.000000    866.388600
# 25%    23748.750000   1431.541100
# 50%    47496.500000   1654.465800
# 75%    71244.250000   1935.993450
# max    94992.000000   3374.399600

# %%
df['energy'].mean()
# Out:
# 1702.9950139487903

# %%
df[['energy']]=df[['energy']].fillna(df['energy'].mean())

# %%
df.describe()
# Out:
#              row_id        energy
# count  94992.000000  94992.000000
# mean   47496.500000   1702.995014
# std    27421.972723    365.609875
# min        1.000000    866.388600
# 25%    23748.750000   1436.432500
# 50%    47496.500000   1664.625600
# 75%    71244.250000   1930.196675
# max    94992.000000   3374.399600

# %%
df.head()
# Out:
#    row_id             datetime       energy
# 0       1  2008-03-01 00:00:00  1259.985563
# 1       2  2008-03-01 01:00:00  1095.541500
# 2       3  2008-03-01 02:00:00  1056.247500
# 3       4  2008-03-01 03:00:00  1034.742000
# 4       5  2008-03-01 04:00:00  1026.334500

# %%
df['year']=df['datetime'].apply(lambda x: x.split()[0].split('-')[0])
df['month']=df['datetime'].apply(lambda x: x.split()[0].split('-')[1])
df['day']=df['datetime'].apply(lambda x: x.split()[0].split('-')[2])

# %%
df.head()
# Out:
#    row_id             datetime       energy  year month day
# 0       1  2008-03-01 00:00:00  1259.985563  2008    03  01
# 1       2  2008-03-01 01:00:00  1095.541500  2008    03  01
# 2       3  2008-03-01 02:00:00  1056.247500  2008    03  01
# 3       4  2008-03-01 03:00:00  1034.742000  2008    03  01
# 4       5  2008-03-01 04:00:00  1026.334500  2008    03  01

# %%
df['year'].unique()
# Out:
# array(['2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018'], dtype=object)

# %%
data=df[['datetime','energy']]

# %%
data.rename({'datetime':'ds','energy':'y'},axis=1,inplace=True)
data.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5047: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   errors=errors,
#                     ds            y
# 0  2008-03-01 00:00:00  1259.985563
# 1  2008-03-01 01:00:00  1095.541500
# 2  2008-03-01 02:00:00  1056.247500
# 3  2008-03-01 03:00:00  1034.742000
# 4  2008-03-01 04:00:00  1026.334500

# %%
data['ds']=pd.to_datetime(data['ds'])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.

# %%
data.dtypes
# Out:
# ds    datetime64[ns]
# y            float64
# dtype: object

# %%
test=pd.read_csv('/content/test_WudNWDM.csv')
test.head()
# Out:
#    row_id             datetime
# 0   94993  2019-01-01 00:00:00
# 1   94994  2019-01-01 01:00:00
# 2   94995  2019-01-01 02:00:00
# 3   94996  2019-01-01 03:00:00
# 4   94997  2019-01-01 04:00:00

# %%
test_data=pd.DataFrame(test['datetime'])
test_data.rename({'datetime':'ds'},axis=1,inplace=True)

# %%
test_data.dtypes
# Out:
# ds    object
# dtype: object

# %%
test_data['ds']=pd.to_datetime(test_data['ds'])

# %%
test_data.head()
# Out:
#                    ds
# 0 2019-01-01 00:00:00
# 1 2019-01-01 01:00:00
# 2 2019-01-01 02:00:00
# 3 2019-01-01 03:00:00
# 4 2019-01-01 04:00:00

# %%
test_data.dtypes
# Out:
# ds    datetime64[ns]
# dtype: object

# %%
from prophet import Prophet

# %%
m_linear = Prophet(growth = 'linear',holidays_prior_scale=20,changepoint_prior_scale=25,seasonality_mode='multiplicative',seasonality_prior_scale=30,weekly_seasonality=False,
                         daily_seasonality = False,yearly_seasonality = False).add_seasonality(name='monthly',period=30.5,fourier_order=55).add_seasonality(
                             name='daily',period=1,fourier_order=10).add_seasonality(name='weekly',period=7,fourier_order=20).add_seasonality(
                                 name='yearly',period=365.25,fourier_order=20).add_seasonality(name='quaterly',period=365.25/4,fourier_order=15,prior_scale=10)
                         
m_linear.fit(data)

future = m_linear.make_future_dataframe(freq='H',periods=24*365)
forecast = m_linear.predict(future)
fig1 = m_linear.plot(forecast)
fig2 = m_linear.plot_components(forecast)
# Out:
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4tlyu9qe/k5ez5o4b.json
# DEBUG:cmdstanpy:input tempfile: /tmp/tmp4tlyu9qe/6p8kh91n.json
# DEBUG:cmdstanpy:idx 0
# DEBUG:cmdstanpy:running CmdStan, num_threads: None
# DEBUG:cmdstanpy:CmdStan args: ['/usr/local/lib/python3.7/dist-packages/prophet/stan_model/prophet_model.bin', 'random', 'seed=88274', 'data', 'file=/tmp/tmp4tlyu9qe/k5ez5o4b.json', 'init=/tmp/tmp4tlyu9qe/6p8kh91n.json', 'output', 'file=/tmp/tmp4tlyu9qe/prophet_modelc7t_oqpq/prophet_model-20221121070915.csv', 'method=optimize', 'algorithm=lbfgs', 'iter=10000']
# 07:09:15 - cmdstanpy - INFO - Chain [1] start processing
# INFO:cmdstanpy:Chain [1] start processing
# 07:17:45 - cmdstanpy - INFO - Chain [1] done processing
# INFO:cmdstanpy:Chain [1] done processing

# %%
future.tail()
# Out:
#                         ds
# 103747 2019-12-31 19:00:00
# 103748 2019-12-31 20:00:00
# 103749 2019-12-31 21:00:00
# 103750 2019-12-31 22:00:00
# 103751 2019-12-31 23:00:00

# %%
test_forecast=m_linear.predict(test_data)

# %%
test_result=test_forecast[['ds','yhat']]

# %%
test_result.dtypes
# Out:
# ds      datetime64[ns]
# yhat           float64
# dtype: object

# %%
plt.figure(figsize=(12,8))
plt.plot(data['ds'],data['y'])
plt.plot(test_result['ds'],test_result['yhat'])
plt.legend(["Old data", "Forecasted data"])

# %%
fig1 = m_linear.plot(test_forecast)
fig2 = m_linear.plot_components(test_forecast)

# %%
output=pd.read_csv('/content/sample_submission_jn0a7vR.csv')

# %%
output['Date Time']=test_result['ds']
output['Energy']=test_result['yhat']

# %%
output.drop(['row_id','energy'],axis=1,inplace=True)

# %%
output.head()
# Out:
#             Date Time       Energy
# 0 2019-01-01 00:00:00  1953.671384
# 1 2019-01-01 01:00:00  1868.218911
# 2 2019-01-01 02:00:00  1825.994489
# 3 2019-01-01 03:00:00  1811.338087
# 4 2019-01-01 04:00:00  1824.776833

# %%
output.to_csv('forecasted_output.csv',index=False)

# %%
k=pd.read_csv('forecasted_output.csv')
k.head()
# Out:
#              Date Time       Energy
# 0  2019-01-01 00:00:00  1953.671384
# 1  2019-01-01 01:00:00  1868.218911
# 2  2019-01-01 02:00:00  1825.994489
# 3  2019-01-01 03:00:00  1811.338087
# 4  2019-01-01 04:00:00  1824.776833
